# %% [markdown]
# # **Bellabeat Case study**
#
# This case study is under Google Data Analyst Certification.
#
# This Analysis helps to solve how trends can inform Bellabeat marketing strategy

# %% [markdown]
# ## **About the company**
# Bellabeat, a high-tech manufacturer of health-focused
# products for women. Bellabeat is a successful small company, but they have the potential to become a larger player in theglobal smart device market.
#
# Urška Sršen and Sando Mur founded Bellabeat, a high-tech company that manufactures health-focused smart products.
# Sršen used her background as an artist to develop beautifully designed technology that informs and inspires women around
# the world. Collecting data on activity, sleep, stress, and reproductive health has allowed Bellabeat to empower women with
# knowledge about their own health and habits. Since it was founded in 2013, Bellabeat has grown rapidly and quickly
# positioned itself as a tech-driven wellness company for women.
#
# By 2016, Bellabeat had opened offices around the world and launched multiple products. Bellabeat products became available
# through a growing number of online retailers in addition to their own e-commerce channel on their website. The company
# has invested in traditional advertising media, such as radio, out-of-home billboards, print, and television, but focuses on digital
# marketing extensively. Bellabeat invests year-round in Google Search, maintaining active Facebook and Instagram pages, and
# consistently engages consumers on Twitter. Additionally, Bellabeat runs video ads on Youtube and display ads on the Google
# Display Network to support campaigns around key marketing dates.
#
# Sršen knows that an analysis of Bellabeat’s available consumer data would reveal more opportunities for growth. She has
# asked the marketing analytics team to focus on a Bellabeat product and analyze smart device usage data in order to gain
# insight into how people are already using their smart devices. Then, using this information, she would like high-level
# recommendations for how these trends can inform Bellabeat marketing strategy.

# %% [markdown]
# ## Ask
#
# 1. What are some trends in smart device usage?
# 2. How could these trends apply to Bellabeat customers?
# 3. How could these trends help influence Bellabeat marketing strategy?
#
# Trends in current smart devices industry and help to create a marketing strategy for Bellabeat

# %% [markdown]
# ## Stakeholders:
# **Urška Sršen:** Bellabeat’s cofounder and Chief Creative Officer
#
# **Sando Mur:** Mathematician and Bellabeat’s cofounder; key member of the Bellabeat executive team

# %% [markdown]
# ## Prepare
# * Reliable - Reliable as data the obtained from specific and collected directly from users with consent.
# * Original - we can consider this as an original as it is released under a license from first party data.
# * Comprehensive - Not comprehensive as some of the data is missing from other tables.
# * Current - Not Current as the data is old
# * Cited - Cited, Data is vetted for public use
#
# **Limitations:**
# The data have less sleep data available, which can skew results.
# Price of products is not available, which we can loose in potential price range.

# %% [markdown]
# ## Process
#
# 1. Data from daily-activity does not contain any duplicates & data seems alright, so I moved on to perform initial Analysis to find patterns in data.
# 2. As moving forward, I would like to find relations between sleeping and daily-activity data.
# 3. The data in 'SleepDay' table seems missing and date is combined with hours. I splitted the data and merged the table with 'daily-activity' on Id and Date.

# %% [markdown]
# ## Analysis

# %% [markdown]
# ![bellabeat_sedetary.png](attachment:3203fca8-eaac-4470-b781-d719285828e3.png)
#
# * Almost 75% of users come under sedentary, This means these users have very-light to moderate activity. We can conclude that most users perform desk jobs
# * Users have Light Active Minutes in a day.
# -> Lifestyle - Sedentary

# %% [markdown]
# ![TotalDistance, VeryActiveDistance, ModeratelyActiveDistance, LightActiveDistance and SedentaryActiveDistance.png](attachment:ad999117-8368-408e-820b-a68e9a05d748.png)
#
# -> This analysis show most of our users have **moderate movement**, which confirms above analysis.

# %% [markdown]
# ![Calories vs. TotalSteps.png](attachment:25f284bb-c2a4-4a55-b0f6-a5619232479a.png)
#
# -> Less daily active steps

# %% [markdown]
# ![TotalTimeInBed vs. TotalMinutesAsleep.png](attachment:e5591591-edb3-4a90-83ea-959fc20e0551.png)
#
# -> This shows positive correlation, in which we can conclude - The more you stay in bed, the more you sleep😀

# %% [markdown]
# ![SedentaryMinutes vs. TotalMinutesAsleep.png](attachment:cc8d47b8-0e19-41d4-9745-cb6751732295.png)
#
# -> As Sedentary Minutes increases sleep-time decreases, Negative correlation

# %% [markdown]
# ## Data insights
#
# 1. 80% users from the have moderate movement in their day.
# 2. More than 75% of sample show that people have Sedentary Jobs/ lifestyle.
# 3. More than 60% of people are taking less than 10,000 steps a day.
# 4. More user stay in bed, more they sleep.
# 5. As sedentary minutes increases, sleep minutes decreases.

# %% [markdown]
# ## Key findings
#
# **1. What are some trends in smart device usage?**
# Most of the user who using smart devices have a sedentary lifestyle, which means most of the users have a deskjobs in which most time they sit.
# Most of the user have a moderate activity, Either going to gym, walking or commute.
# Sedentary Minutes are more than they sleep.
#
# **2. How could these trends apply to Bellabeat customers?**
# As Bellabeat offers similar products, Most of the Bellabeats will be from these backgrounds. As this data is from existing market, most of the users stay in same bracket.
#
# **3. How could these trends help influence Bellabeat marketing strategy?**
# With above trends Bellabeat can come-up with a personalized marketing strategy, which helps them to reach target audience accurately.

# %% [markdown]
# ## Recommendations
# 1. We can post ads on websites and streaming sites where most of our user active.
# 2. We can place bill boards in Gyms, public places and company areas where most of companies present.
# 3. **Sping** and **Time** can be more used as Time have multiple featues where user can track time and activity. Spring will help user with their Hydration💧 and stay on desk.
# 4. Personalized membership recommendations will be made for those targets audience with less activity and sleep, As Bellabeat membership offers nutrition, activity, sleep, health and beauty. We can make more personlized about various health benifits they can gain.

# %% [markdown]
# **> Thank you😊 for staying and reading.**
# Add some suggestions and let me know any mistake as this is my first Analysis project.
# - I used Google sheets for this project. Thank you sheets😅😅

# %%
print('Namaste 🙏')
# Out:
# [1] "Namaste 🙏"

# %%
install.packages('tidyverse')
library('tidyverse')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “unable to access index for repository http://cran.rstudio.com/src/contrib:
#   cannot open URL 'http://cran.rstudio.com/src/contrib/PACKAGES'”
# Warning message:
# “package ‘tidyverse’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.4     ✔ purrr   0.3.4
# ✔ tibble  3.1.2     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
